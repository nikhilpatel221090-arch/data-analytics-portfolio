# %%
# Customer Complaints Data Cleaning

import pandas as pd

# Load the raw dataset
raw = pd.read_csv("raw_customer_complaints.csv")
print("🔹 Raw Data Sample")
display(raw.head())

# Step 1: Check column names & data info
print("\n🔹 Dataset Info")
print(raw.info())

print("\n🔹 Missing Values Count")
print(raw.isnull().sum())

# Step 2: Remove duplicates
no_duplicates = raw.drop_duplicates()

# Step 3: Handle missing values (drop rows with nulls)
cleaned = no_duplicates.dropna()

# Step 4: Save cleaned dataset
cleaned.to_csv("cleaned_customer_complaints.csv", index=False)

print("\n✅ Cleaning complete! Saved as cleaned_customer_complaints.csv")

# Show cleaned data preview
display(cleaned.head())
# Out:
# 🔹 Raw Data Sample
#    CustomerID        Complaint  Satisfaction
# 0         1.0    Late delivery           3.0
# 1         2.0  Damaged product           2.0
# 2         2.0  Damaged product           2.0
# 3         3.0       Wrong item           1.0
# 4         4.0    Late delivery           4.0
# 🔹 Dataset Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    6 non-null      float64
#  1   Complaint     6 non-null      object
#  2   Satisfaction  6 non-null      float64
# dtypes: float64(2), object(1)
# memory usage: 300.0+ bytes
# None
#
# 🔹 Missing Values Count
# CustomerID      1
# Complaint       1
# Satisfaction    1
# dtype: int64
#
# ✅ Cleaning complete! Saved as cleaned_customer_complaints.csv
#    CustomerID        Complaint  Satisfaction
# 0         1.0    Late delivery           3.0
# ...
